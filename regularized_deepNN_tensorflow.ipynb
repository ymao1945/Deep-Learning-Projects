# %% [markdown]
# # Image Application: cat or not?
#
# **After this assignment you will be able to:**
# - Build and apply a deep neural network to supervised learning.
# - Learn how to do data normalization
# - learn how to do weight initialization
# - Learn how to use regularization
#
# Let's get started!

# %% [markdown]
# ## 1 - Packages

# %% [markdown]
# **Exercise**: Please mount your Google drive, and set up your working folder here.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
# start your code here
os.chdir("/content/drive/MyDrive/Deep Learning in Practice/Homework4/regularization_tf") # change your working folder here
# end your code here

# %% [markdown]
# Let's first import all the packages that you will need during this assignment.
# - [numpy](https://www.numpy.org/) is the fundamental package for scientific computing with Python.
# - [matplotlib](http://matplotlib.org) is a library to plot graphs in Python.
# - [h5py](http://www.h5py.org) is a common package to interact with a dataset that is stored on an H5 file.
# - [PIL](http://www.pythonware.com/products/pil/) and [scipy](https://www.scipy.org/) are used here to test your model with your own picture at the end.
# - dnn_app_utils provides the customized functions that will be used in this notebook.
# - np.random.seed(1) is used to keep all the random function calls consistent. It will help us grade your work.

# %%
import time
import numpy as np
import tensorflow as tf
import h5py
import matplotlib.pyplot as plt
import dnn_app_utils_v3 as du
from skimage.transform import rescale, resize, downscale_local_mean

# refresh 'planar_utils' module
import imp
imp.reload(du)

# %matplotlib inline
plt.rcParams['figure.figsize'] = (5.0, 4.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %load_ext autoreload
# %autoreload 2

np.random.seed(1)
tf.random.set_seed(1)

# %% [markdown]
# ## 2 - Dataset
#
# **Problem Statement**: You are given a dataset ("data.h5") containing:
#     - a training set of m_train images labelled as cat (1) or non-cat (0)
#     - a test set of m_test images labelled as cat and non-cat
#     - each image is of shape (num_px, num_px, 3) where 3 is for the 3 channels (RGB).
#
# Let's get more familiar with the dataset. Load the data by running the cell below.
#
# The training input and output are stored in 'train_x_orig' and 'train_y'. The test input and output are stored in 'test_x_orig' and 'test_y'.

# %%
train_x_orig, train_y, test_x_orig, test_y, classes = du.load_data()
train_y = train_y.T
test_y = test_y.T
#print(classes)

# %% [markdown]
# The following code will show you an image in the dataset. Feel free to change the index and re-run the cell multiple times to see other images.

# %%
# Example of a picture
index = 200
plt.imshow(train_x_orig[index])
print("y = " + str(train_y[index,0]) + ". It's a " + classes[train_y[index,0]].decode("utf-8") +  " picture.")
#print(train_x_orig[index].shape,train_x_orig[index])
# Out:
# y = 1. It's a cat picture.

# %% [markdown]
# Let's explore more about the training data. We are curious about the shape of each image and can use 'train_x_orig[index].shape' to expore it.
# **Exercise**: Can you tell what the pixel number of each image is?

# %%
# Explore your dataset 
image_shape=train_x_orig[index].shape
print("Each image is of size: ", image_shape)
#start your code here
num_px=image_shape[0]   # the number of pixels in each column of the image. Hint: The 1st element in image_shape indicates this number?
#end your code here
print('Number of pixels in each column of the image:', num_px)
# Out:
# Each image is of size:  (64, 64, 3)
# Number of pixels in each column of the image: 64

# %% [markdown]
# We just take a close look at an image of the image set. Now, let's take a look at the whole training set.
#
# **Exercise**: The first 4 lines in the following cell print out the shape of the trining images. There are 209 images, and each image has 64 by 64 pixcels and GRB color.
#
# Please print out the shape of the test input (stored in `test_x_orig`) and output (stored in `test_y`) data, and tell how many images we have in the test data.

# %%
train_x_shape=train_x_orig.shape
m_train = train_x_shape[0]
print ("train_x_orig shape: ",train_x_shape)
print ("Number of training examples: " ,m_train)
# start your code here
test_x_shape=np.shape(test_x_orig)
test_y_shape=np.shape(test_y)
m_test = test_x_orig.shape[0]
# end your code here

print ("test_x_orig shape: " ,test_x_shape)
print ("test_y shape: " , test_y_shape)
print ("Number of test examples: " ,m_test)
# Out:
# train_x_orig shape:  (209, 64, 64, 3)
# Number of training examples:  209
# test_x_orig shape:  (50, 64, 64, 3)
# test_y shape:  (50, 1)
# Number of test examples:  50

# %% [markdown]
# As mentioned in our lecture, you reshape and standardize the images before feeding them to the network. The code is given in the cell below.
#
# ![alt text](https://drive.google.com/uc?id=12XXwVJpcT-moegSdzejC-W-hD79qDSk9)
# <caption><center> <u>Figure 1</u>: Image to vector conversion. <br> </center></caption>

# %%
# Reshape the training and test examples 
train_x_flatten = train_x_orig.reshape(train_x_shape[0], -1)   # The "-1" makes reshape flatten the remaining dimensions
test_x_flatten = test_x_orig.reshape(test_x_orig.shape[0], -1)

# %% [markdown]
# Data normalization can help us accelerate the training process. The RGB values of an image are integers in the range of [0,255]. We can normalize the training images to have the feature values between 0 and 1 by using `train_x = train_x_flatten/255.0`.
#
# **Exercise**: We normalize the training images using `train_x = train_x_flatten/255.0` in the 1st line. Please normalize the test images to have feature values between 0 and 1.

# %%
# Standardize data to have feature values between 0 and 1.
train_x = train_x_flatten/255.0

#start your code here
test_x = test_x_flatten/255.0
#end your code here

print ("train_x's shape: " + str(train_x.shape))
print ("test_x's shape: " + str(test_x.shape))
print ("train_y's shape: " + str(train_y.shape))
print ("test_y's shape: " + str(test_y.shape))
# Out:
# train_x's shape: (209, 12288)
# test_x's shape: (50, 12288)
# train_y's shape: (209, 1)
# test_y's shape: (50, 1)

# %% [markdown]
# ###3- Build your neural network ###
# Now, we are going to use the skills in the first module to build our neural network.
#
# Excep the input layer, you can use
#
# `tf.keras.layers.Dense(20,activation='relu',
#                             kernel_initializer='glorot_uniform',
#                             bias_initializer='zeros')`
#
# to build the layers. In this example, we have 20 neurons in this layer, use 'relu' as the activation function, initialize our weight randomly using 'glorot_uniform', and our bias is initialized to be 'zeros'.
#
# First, we will need an input layer. How many neurons will you need in the input layer? Hint: how many elements does every training input have?
#
# Second, we will build several hidden layers. You are free to choose the number of neurons in every hidden layer.
#
# Last, we will build the output layer. How many neurons will you need in the output layer? Which activation function is more suitale in this problem? Hint: how many elements does every training output have? What is the range of the training output?

# %%
tf.random.set_seed(1) # we fixed the seed of the random number generator, so every time running this code, we can have the same results.

# start your code here
cat_model=tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=(train_x.shape[1])), # how many elements are there in every training image?
    tf.keras.layers.Dense(20,activation='relu', # in layer 1, we will have 20 neurons and use 'relu' as the activation function
                            kernel_initializer='glorot_uniform', # we will randomly choose the initial weight using the 'glorot_uniform' method
                            bias_initializer='zeros'), # we will initialize all bias to be zeros.
    #please follow the example of layer 1 to add more hidden layers here. 
    tf.keras.layers.Dense(15,activation='relu', kernel_initializer='glorot_uniform', bias_initializer='zeros'),
    tf.keras.layers.Dense(1,activation='sigmoid', # how many elements are there in every training output
                            kernel_initializer='glorot_uniform', 
                            bias_initializer='zeros'),
])
# end your code here
cat_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 20)                245780
#
#  dense_1 (Dense)             (None, 15)                315
#
#  dense_2 (Dense)             (None, 1)                 16
#
# =================================================================
# Total params: 246,111
# Trainable params: 246,111
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Now, let's compile the model. When comiling your model, you will need to specify the optimizer, the loss function, and the metrics.
#
# For optimizers, the most popular ones are 'Adam' and its derivatives. You can also try 'RMSprop' and 'SGD' to see which one works better for you. You might need adjust the learning rate to acceperate the training process.
#
# For loss functions, our problem is a two-class classification problem. The most popular loss function would be 'BinaryCrossentropy'. If this is a multiple-class classification problem, you probably want to try 'CategoricalCrossentropy' or 'SparseCategoricalCrossentropy'.
#
# For the metrics, we want to know the accuracy of our model. Therefore, I would recommend 'accuracy'.

# %%
# start your code here
cat_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),  # Optimizer. Please change 'None' to some meaningful learning rate which is usually <1
    # Loss function to minimize
    loss=tf.keras.losses.BinaryCrossentropy(),
    # List of metrics to monitor
    metrics=['accuracy'],
                 )
# end your code here

# %% [markdown]
# It's time to train.
#
# We can plot training history. It can help us to adjust the parameters.
#
# If the training loss increases, we may want to decrease the `learning_rate`.
#
# If the training loss has large vibration, we may want to decrease the `learning_rate`.
#
# If the training loss decreases too slowly, we need to increase `learning_rate`.
#
# If the training loss decreases at a good speed, but ends up large, we may want to increase the epoch number.

# %%
# start your code here
history = cat_model.fit(
    train_x, # input data
    train_y, # real output data
    validation_split=0.15, # this number is usually betwwen 0 and 0.3. It is the portion used as validation data, 
    epochs=100, # how many iterations do you want to train your model? Your data will be reused to train the model for the number of epochs. I trained 5 min for this model
)
# end your code here. 
plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['loss','val_loss'])
# Out:
# Epoch 1/100
# 6/6 [==============================] - 1s 45ms/step - loss: 1.0561 - accuracy: 0.4576 - val_loss: 0.8558 - val_accuracy: 0.2188
# Epoch 2/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6655 - accuracy: 0.5593 - val_loss: 0.5679 - val_accuracy: 0.7812
# Epoch 3/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.6801 - accuracy: 0.6328 - val_loss: 0.6244 - val_accuracy: 0.7500
# Epoch 4/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6984 - accuracy: 0.4520 - val_loss: 0.6162 - val_accuracy: 0.7812
# Epoch 5/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.6832 - accuracy: 0.6328 - val_loss: 0.5539 - val_accuracy: 0.7812
# Epoch 6/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6686 - accuracy: 0.6328 - val_loss: 0.6030 - val_accuracy: 0.7812
# Epoch 7/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6552 - accuracy: 0.6328 - val_loss: 0.5840 - val_accuracy: 0.7812
# Epoch 8/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6591 - accuracy: 0.6328 - val_loss: 0.5598 - val_accuracy: 0.7812
# Epoch 9/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.6429 - accuracy: 0.6554 - val_loss: 0.6520 - val_accuracy: 0.6250
# Epoch 10/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6302 - accuracy: 0.6328 - val_loss: 0.5539 - val_accuracy: 0.7500
# Epoch 11/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6278 - accuracy: 0.6384 - val_loss: 0.5766 - val_accuracy: 0.7500
# Epoch 12/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6183 - accuracy: 0.6667 - val_loss: 0.6112 - val_accuracy: 0.6875
# Epoch 13/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6172 - accuracy: 0.6497 - val_loss: 0.5623 - val_accuracy: 0.7500
# Epoch 14/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6133 - accuracy: 0.6667 - val_loss: 0.6037 - val_accuracy: 0.6875
# Epoch 15/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.5866 - accuracy: 0.6667 - val_loss: 0.5689 - val_accuracy: 0.7500
# Epoch 16/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.
100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1564 - accuracy: 0.9605 - val_loss: 0.9248 - val_accuracy: 0.5625
# Epoch 79/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1365 - accuracy: 0.9774 - val_loss: 0.9246 - val_accuracy: 0.5938
# Epoch 80/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1438 - accuracy: 0.9774 - val_loss: 0.9457 - val_accuracy: 0.5625
# Epoch 81/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1246 - accuracy: 0.9887 - val_loss: 0.9448 - val_accuracy: 0.5938
# Epoch 82/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1286 - accuracy: 0.9718 - val_loss: 0.9415 - val_accuracy: 0.5938
# Epoch 83/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1281 - accuracy: 0.9831 - val_loss: 0.9584 - val_accuracy: 0.5625
# Epoch 84/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1166 - accuracy: 0.9831 - val_loss: 0.9526 - val_accuracy: 0.5938
# Epoch 85/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1146 - accuracy: 0.9887 - val_loss: 0.9623 - val_accuracy: 0.5625
# Epoch 86/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1248 - accuracy: 0.9661 - val_loss: 0.9826 - val_accuracy: 0.5625
# Epoch 87/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.1141 - accuracy: 0.9831 - val_loss: 0.9963 - val_accuracy: 0.5625
# Epoch 88/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1115 - accuracy: 0.9887 - val_loss: 0.9912 - val_accuracy: 0.5938
# Epoch 89/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1069 - accuracy: 0.9887 - val_loss: 0.9955 - val_accuracy: 0.5938
# Epoch 90/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1010 - accuracy: 0.9887 - val_loss: 1.0014 - val_accuracy: 0.5938
# Epoch 91/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0965 - accuracy: 0.9944 - val_loss: 1.0473 - val_accuracy: 0.5312
# Epoch 92/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1056 - accuracy: 0.9887 - val_loss: 1.0199 - val_accuracy: 0.5938
# Epoch 93/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.0942 - accuracy: 0.9944 - val_loss: 1.0338 - val_accuracy: 0.5938
# Epoch 94/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0892 - accuracy: 0.9944 - val_loss: 1.0471 - val_accuracy: 0.5625
# Epoch 95/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.0951 - accuracy: 0.9887 - val_loss: 1.0601 - val_accuracy: 0.5625
# Epoch 96/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0864 - accuracy: 0.9944 - val_loss: 1.0881 - val_accuracy: 0.6562
# Epoch 97/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0876 - accuracy: 0.9944 - val_loss: 1.1757 - val_accuracy: 0.5312
# Epoch 98/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1347 - accuracy: 0.9605 - val_loss: 1.0882 - val_accuracy: 0.6250
# Epoch 99/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0987 - accuracy: 0.9887 - val_loss: 1.1232 - val_accuracy: 0.6562
# Epoch 100/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1258 - accuracy: 0.9718 - val_loss: 1.1904 - val_accuracy: 0.5312

# %% [markdown]
# ### 4. test ###
# Let us test their performance using our test dataset. The test dataset is never used to train the models, and reflects the acutual performance of the model when it is used in the general images.
#
# To evaluate the model , we can use
# `cat_model.evaluate(test_x,test_y)`.

# %%
cat_model.evaluate(test_x,test_y)
# Out:
# 2/2 [==============================] - 0s 9ms/step - loss: 0.9264 - accuracy: 0.7800
# [0.9264160394668579, 0.7799999713897705]

# %% [markdown]
# The expected accuracy is higher than 0.7. If the accuracy is lower than 0.7, you may want to increase the epoch number, adjust the learning rate, and the regularizer weight, to achieve the goal.
#
# For your reference, I trained the model for 5 min to achieve that goal.
#
# If you have achieved the 0.7 goal, I would like to challenge you for the 0.8 accuracy for the test set.

# %% [markdown]
# ### 5- Adding Regularization ###
# After enough training, you probably notice that while the training loss is very small, the validation loss is quite large. This is what we called **low bias high vairance** problem. We have several ways to deal with it,
# 1. L1/L2 regularization,
# 2. drop out, and
# 3. early stop.
#
# I would recommend you try the regularization first, because it's easy to use and usually works.
#
# To add regularization to the network, we only need to specify this option in the 'Dense' layer as follows.
#
# `tf.keras.layers.Dense(20,activation='relu',
#                           kernel_initializer='glorot_uniform',
#                           bias_initializer='zeros',
#                           kernel_regularizer=tf.keras.regularizers.L2(0.01))`
#
# The parameter **kernel_regularizer=tf.keras.regularizers.L2(0.01)** says that we want an 'L2' regularizer with weight 0.01. A higher weight usually can reduce the validation loss more. But if the weight is too large, the training loss might redecus very slowly.

# %%
tf.random.set_seed(1)
cat_model_regu=tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=(12288,)),
    tf.keras.layers.Dense(20,activation='relu', # in layer 1, we will have 20 neurons and use 'relu'
                          kernel_initializer='glorot_uniform',# we will randomly choose the initial weight using the 'glorot_uniform' method as the activation function
                          bias_initializer='zeros', # we will initialize all bias to be zeros.
                          kernel_regularizer=tf.keras.regularizers.L2(0.06)), # L2-regularization can be added here
    #please feel free to add more hidden layers with regularizer
    tf.keras.layers.Dense(15,activation='relu', kernel_initializer='glorot_uniform', bias_initializer='zeros',
                          kernel_regularizer = tf.keras.regularizers.L2(0.06)),
    # End adding hidden layers 
    tf.keras.layers.Dense(1,activation='sigmoid', 
                            kernel_initializer='glorot_uniform',
                            bias_initializer='zeros', 
                            kernel_regularizer=tf.keras.regularizers.L2(0.06)),
])

cat_model_regu.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 20)                245780
#
#  dense_4 (Dense)             (None, 15)                315
#
#  dense_5 (Dense)             (None, 1)                 16
#
# =================================================================
# Total params: 246,111
# Trainable params: 246,111
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Now, you can compile and train the regularized neural network as before.

# %%
# start your code here
cat_model_regu.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),  # Optimizer please change "None" to some meaningful number here
    # Loss function to minimize
    loss=tf.keras.losses.BinaryCrossentropy(),
    # List of metrics to monitor
    metrics=['accuracy'],
                 )
# end your code here.

# %%
# start your code here
history_regu = cat_model_regu.fit(
    train_x, # input data
    train_y, # real output data
    validation_split=0.20, # this number is usually betwwen 0 and 0.3. It is the portion used as validation data, 
    epochs=500, # how many iterations do you want to train your model? Your data will be reused to train the model for the number of epochs. I trained 5 min for this model
)
# end your code here

plt.figure()
plt.plot(history_regu.history['loss'])
plt.plot(history_regu.history['val_loss'])
plt.legend(['loss','val_loss'])
# Out:
# Epoch 1/500
# 6/6 [==============================] - 1s 47ms/step - loss: 4.1909 - accuracy: 0.5449 - val_loss: 3.6162 - val_accuracy: 0.7143
# Epoch 2/500
# 6/6 [==============================] - 0s 13ms/step - loss: 3.4515 - accuracy: 0.6527 - val_loss: 2.9857 - val_accuracy: 0.5952
# Epoch 3/500
# 6/6 [==============================] - 0s 12ms/step - loss: 2.8198 - accuracy: 0.6347 - val_loss: 2.5794 - val_accuracy: 0.6905
# Epoch 4/500
# 6/6 [==============================] - 0s 13ms/step - loss: 2.5094 - accuracy: 0.6467 - val_loss: 2.3885 - val_accuracy: 0.6190
# Epoch 5/500
# 6/6 [==============================] - 0s 13ms/step - loss: 2.2858 - accuracy: 0.6826 - val_loss: 2.2011 - val_accuracy: 0.6429
# Epoch 6/500
# 6/6 [==============================] - 0s 12ms/step - loss: 2.1689 - accuracy: 0.6048 - val_loss: 2.1083 - val_accuracy: 0.5952
# Epoch 7/500
# 6/6 [==============================] - 0s 15ms/step - loss: 1.9833 - accuracy: 0.6826 - val_loss: 2.0160 - val_accuracy: 0.5000
# Epoch 8/500
# 6/6 [==============================] - 0s 12ms/step - loss: 1.
500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4270 - accuracy: 0.9820 - val_loss: 1.1696 - val_accuracy: 0.6429
# Epoch 331/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4326 - accuracy: 0.9820 - val_loss: 1.1304 - val_accuracy: 0.5238
# Epoch 332/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4123 - accuracy: 0.9940 - val_loss: 1.1189 - val_accuracy: 0.4524
# Epoch 333/500
# 6/6 [==============================] - 0s 21ms/step - loss: 0.4177 - accuracy: 1.0000 - val_loss: 1.1285 - val_accuracy: 0.4286
# Epoch 334/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.4144 - accuracy: 0.9940 - val_loss: 1.1381 - val_accuracy: 0.4762
# Epoch 335/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4170 - accuracy: 0.9940 - val_loss: 1.1489 - val_accuracy: 0.5000
# Epoch 336/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4100 - accuracy: 0.9940 - val_loss: 1.1623 - val_accuracy: 0.4286
# Epoch 337/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.4133 - accuracy: 0.9940 - val_loss: 1.1583 - val_accuracy: 0.4762
# Epoch 338/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.4142 - accuracy: 0.9940 - val_loss: 1.1702 - val_accuracy: 0.5238
# Epoch 339/500
# ...
# Epoch 389/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4155 - accuracy: 0.9940 - val_loss: 1.1761 - val_accuracy: 0.5238
# Epoch 390/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4167 - accuracy: 1.0000 - val_loss: 1.1756 - val_accuracy: 0.4286
# Epoch 391/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4237 - accuracy: 0.9701 - val_loss: 1.4341 - val_accuracy: 0.6429
# Epoch 392/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.4834 - accuracy: 0.9281 - val_loss: 1.2180 - val_accuracy: 0.6429
# Epoch 393/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4494 - accuracy: 0.9641 - val_loss: 1.1711 - val_accuracy: 0.4524
# Epoch 394/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4136 - accuracy: 0.9940 - val_loss: 1.1971 - val_accuracy: 0.6190
# Epoch 395/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.4168 - accuracy: 1.0000 - val_loss: 1.1792 - val_accuracy: 0.5238
# Epoch 396/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4085 - accuracy: 1.0000 - val_loss: 1.2273 - val_accuracy: 0.3810
# Epoch 397/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.4218 - accuracy: 0.9940 - val_loss: 1.2014 - val_accuracy: 0.5238
# Epoch 398/500
# 6/6 [==============================] - 0s 21ms/step - loss: 0.4079 - accuracy: 0.9940 - val_loss: 1.2041 - val_accuracy: 0.4286
# Epoch 399/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4106 - accuracy: 0.9880 - val_loss: 1.1932 - val_accuracy: 0.5714
# Epoch 400/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4085 - accuracy: 0.9880 - val_loss: 1.1902 - val_accuracy: 0.5714
# Epoch 401/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.4470 - accuracy: 0.9701 - val_loss: 1.2107 - val_accuracy: 0.5476
# Epoch 402/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.4904 - accuracy: 0.9281 - val_loss: 1.2498 - val_accuracy: 0.3571
# Epoch 403/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.4795 - accuracy: 0.9341 - val_loss: 1.7033 - val_accuracy: 0.3810
# Epoch 404/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.5614 - accuracy: 0.8802 - val_loss: 1.5378 - val_accuracy: 0.4048
# Epoch 405/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5592 - accuracy: 0.8383 - val_loss: 1.2432 - val_accuracy: 0.3810
# Epoch 406/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4976 - accuracy: 0.9341 - val_loss: 1.2162 - val_accuracy: 0.4762
# Epoch 407/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4387 - accuracy: 0.9701 - val_loss: 1.2460 - val_accuracy: 0.5238
# Epoch 408/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.4138 - accuracy: 1.0000 - val_loss: 1.4291 - val_accuracy: 0.6667
# Epoch 409/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.5360 - accuracy: 0.8743 - val_loss: 1.2360 - val_accuracy: 0.6429
# Epoch 410/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.5450 - accuracy: 0.8623 - val_loss: 1.1632 - val_accuracy: 0.5476
# Epoch 411/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.5565 - accuracy: 0.8743 - val_loss: 1.1910 - val_accuracy: 0.4286
# Epoch 412/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.5114 - accuracy: 0.8982 - val_loss: 1.2074 - val_accuracy: 0.5476
# Epoch 413/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.5531 - accuracy: 0.8802 - val_loss: 1.3353 - val_accuracy: 0.4762
# Epoch 414/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.5449 - accuracy: 0.8683 - val_loss: 1.1222 - val_accuracy: 0.4524
# Epoch 415/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4828 - accuracy: 0.9162 - val_loss: 1.3358 - val_accuracy: 0.4762
# Epoch 416/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5188 - accuracy: 0.9162 - val_loss: 1.1783 - val_accuracy: 0.4048
# Epoch 417/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4733 - accuracy: 0.9641 - val_loss: 1.1130 - val_accuracy: 0.5714
# Epoch 418/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4543 - accuracy: 0.9820 - val_loss: 1.1757 - val_accuracy: 0.5238
# Epoch 419/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4333 - accuracy: 0.9820 - val_loss: 1.4531 - val_accuracy: 0.6667
# Epoch 420/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5227 - accuracy: 0.9042 - val_loss: 1.3171 - val_accuracy: 0.6429
# Epoch 421/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4630 - accuracy: 0.9461 - val_loss: 1.4047 - val_accuracy: 0.4524
# Epoch 422/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.4560 - accuracy: 0.9760 - val_loss: 1.2111 - val_accuracy: 0.4048
# Epoch 423/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4193 - accuracy: 0.9940 - val_loss: 1.1783 - val_accuracy: 0.5000
# Epoch 424/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4137 - accuracy: 0.9940 - val_loss: 1.1672 - val_accuracy: 0.5000
# Epoch 425/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.4111 - accuracy: 0.9940 - val_loss: 1.2328 - val_accuracy: 0.4048
# Epoch 426/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4409 - accuracy: 0.9820 - val_loss: 1.1369 - val_accuracy: 0.5476
# Epoch 427/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4139 - accuracy: 1.0000 - val_loss: 1.1278 - val_accuracy: 0.5238
# Epoch 428/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.4121 - accuracy: 1.0000 - val_loss: 1.1664 - val_accuracy: 0.5952
# Epoch 429/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4319 - accuracy: 0.9880 - val_loss: 1.3330 - val_accuracy: 0.6429
# Epoch 430/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4833 - accuracy: 0.9461 - val_loss: 1.1629 - val_accuracy: 0.5000
# Epoch 431/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.4375 - accuracy: 0.9701 - val_loss: 1.3030 - val_accuracy: 0.3810
# Epoch 432/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4253 - accuracy: 0.9880 - val_loss: 1.2268 - val_accuracy: 0.5714
# Epoch 433/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4167 - accuracy: 0.9940 - val_loss: 1.1791 - val_accuracy: 0.5000
# Epoch 434/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.4084 - accuracy: 0.9940 - val_loss: 1.2202 - val_accuracy: 0.4286
# Epoch 435/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.4367 - accuracy: 0.9641 - val_loss: 1.2260 - val_accuracy: 0.3810
# Epoch 436/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4763 - accuracy: 0.9581 - val_loss: 1.2783 - val_accuracy: 0.4048
# Epoch 437/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4575 - accuracy: 0.9641 - val_loss: 1.1862 - val_accuracy: 0.5238
# Epoch 438/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.4152 - accuracy: 0.9880 - val_loss: 1.1797 - val_accuracy: 0.5952
# Epoch 439/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4051 - accuracy: 1.0000 - val_loss: 1.2164 - val_accuracy: 0.3810
# Epoch 440/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4213 - accuracy: 0.9880 - val_loss: 1.1952 - val_accuracy: 0.4048
# Epoch 441/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4452 - accuracy: 0.9760 - val_loss: 1.1960 - val_accuracy: 0.5476
# Epoch 442/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.4184 - accuracy: 0.9820 - val_loss: 1.2279 - val_accuracy: 0.6190
# Epoch 443/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4453 - accuracy: 0.9760 - val_loss: 1.2155 - val_accuracy: 0.6190
# Epoch 444/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.4172 - accuracy: 1.0000 - val_loss: 1.1982 - val_accuracy: 0.4048
# Epoch 445/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4435 - accuracy: 0.9760 - val_loss: 1.1516 - val_accuracy: 0.5000
# Epoch 446/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4100 - accuracy: 1.0000 - val_loss: 1.1736 - val_accuracy: 0.6190
# Epoch 447/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4213 - accuracy: 0.9880 - val_loss: 1.1835 - val_accuracy: 0.6190
# Epoch 448/500
# 6/6 [==============================] - 0s 24ms/step - loss: 0.4131 - accuracy: 0.9940 - val_loss: 1.1840 - val_accuracy: 0.5000
# Epoch 449/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.4044 - accuracy: 1.0000 - val_loss: 1.2236 - val_accuracy: 0.5476
# Epoch 450/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.4134 - accuracy: 1.0000 - val_loss: 1.1729 - val_accuracy: 0.4762
# Epoch 451/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4168 - accuracy: 1.0000 - val_loss: 1.3729 - val_accuracy: 0.4762
# Epoch 452/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.5035 - accuracy: 0.9042 - val_loss: 1.2524 - val_accuracy: 0.3810
# Epoch 453/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4402 - accuracy: 0.9641 - val_loss: 1.2874 - val_accuracy: 0.4048
# Epoch 454/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.4946 - accuracy: 0.9401 - val_loss: 1.1506 - val_accuracy: 0.4524
# Epoch 455/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.4252 - accuracy: 0.9940 - val_loss: 1.1527 - val_accuracy: 0.5476
# Epoch 456/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.4250 - accuracy: 0.9820 - val_loss: 1.1685 - val_accuracy: 0.5238
# Epoch 457/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4149 - accuracy: 0.9880 - val_loss: 1.3121 - val_accuracy: 0.6429
# Epoch 458/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.4697 - accuracy: 0.9401 - val_loss: 1.3571 - val_accuracy: 0.6429
# Epoch 459/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.5290 - accuracy: 0.9222 - val_loss: 1.3671 - val_accuracy: 0.6429
# Epoch 460/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.5460 - accuracy: 0.8683 - val_loss: 1.2685 - val_accuracy: 0.6429
# Epoch 461/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.4765 - accuracy: 0.9461 - val_loss: 1.3267 - val_accuracy: 0.6429
# Epoch 462/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.4903 - accuracy: 0.9341 - val_loss: 1.1985 - val_accuracy: 0.5714
# Epoch 463/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5814 - accuracy: 0.8383 - val_loss: 1.2561 - val_accuracy: 0.6429
# Epoch 464/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.7856 - accuracy: 0.8084 - val_loss: 1.5168 - val_accuracy: 0.3333
# Epoch 465/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.7450 - accuracy: 0.7964 - val_loss: 1.1361 - val_accuracy: 0.6429
# Epoch 466/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.5569 - accuracy: 0.9401 - val_loss: 1.0591 - val_accuracy: 0.6190
# Epoch 467/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.5677 - accuracy: 0.8862 - val_loss: 1.0697 - val_accuracy: 0.4524
# Epoch 468/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.5143 - accuracy: 0.9701 - val_loss: 1.1252 - val_accuracy: 0.5238
# Epoch 469/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4490 - accuracy: 0.9880 - val_loss: 1.2077 - val_accuracy: 0.3810
# Epoch 470/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4530 - accuracy: 0.9940 - val_loss: 1.2536 - val_accuracy: 0.4048
# Epoch 471/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.4539 - accuracy: 0.9760 - val_loss: 1.1749 - val_accuracy: 0.5000
# Epoch 472/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.4248 - accuracy: 1.0000 - val_loss: 1.2296 - val_accuracy: 0.3810
# Epoch 473/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.4416 - accuracy: 0.9760 - val_loss: 1.2186 - val_accuracy: 0.5952
# Epoch 474/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.4174 - accuracy: 0.9940 - val_loss: 1.2462 - val_accuracy: 0.6429
# Epoch 475/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.4802 - accuracy: 0.9281 - val_loss: 1.1949 - val_accuracy: 0.5476
# Epoch 476/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4862 - accuracy: 0.9042 - val_loss: 1.2458 - val_accuracy: 0.3571
# Epoch 477/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.4278 - accuracy: 0.9760 - val_loss: 1.2742 - val_accuracy: 0.4048
# Epoch 478/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.4339 - accuracy: 0.9820 - val_loss: 1.2514 - val_accuracy: 0.4286
# Epoch 479/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.4275 - accuracy: 0.9940 - val_loss: 1.2146 - val_accuracy: 0.4762
# Epoch 480/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.4139 - accuracy: 1.0000 - val_loss: 1.1855 - val_accuracy: 0.5476
# Epoch 481/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4120 - accuracy: 0.9940 - val_loss: 1.1834 - val_accuracy: 0.4048
# Epoch 482/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4133 - accuracy: 0.9880 - val_loss: 1.1715 - val_accuracy: 0.5714
# Epoch 483/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.4241 - accuracy: 0.9880 - val_loss: 1.1904 - val_accuracy: 0.6429
# Epoch 484/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.4165 - accuracy: 0.9940 - val_loss: 1.1647 - val_accuracy: 0.5238
# Epoch 485/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4112 - accuracy: 0.9820 - val_loss: 1.1826 - val_accuracy: 0.5238
# Epoch 486/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4066 - accuracy: 1.0000 - val_loss: 1.2263 - val_accuracy: 0.3810
# Epoch 487/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4271 - accuracy: 0.9760 - val_loss: 1.1758 - val_accuracy: 0.5476
# Epoch 488/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.4050 - accuracy: 1.0000 - val_loss: 1.1692 - val_accuracy: 0.5476
# Epoch 489/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4073 - accuracy: 1.0000 - val_loss: 1.1844 - val_accuracy: 0.5476
# Epoch 490/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4170 - accuracy: 1.0000 - val_loss: 1.1734 - val_accuracy: 0.5476
# Epoch 491/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4173 - accuracy: 0.9760 - val_loss: 1.2811 - val_accuracy: 0.4048
# Epoch 492/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4577 - accuracy: 0.9641 - val_loss: 1.3799 - val_accuracy: 0.4524
# Epoch 493/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4929 - accuracy: 0.9461 - val_loss: 1.2244 - val_accuracy: 0.3810
# Epoch 494/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.4963 - accuracy: 0.9102 - val_loss: 1.1996 - val_accuracy: 0.6429
# Epoch 495/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.5594 - accuracy: 0.8743 - val_loss: 1.1366 - val_accuracy: 0.5000
# Epoch 496/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.6346 - accuracy: 0.8503 - val_loss: 1.3463 - val_accuracy: 0.6429
# Epoch 497/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.5239 - accuracy: 0.8982 - val_loss: 1.4916 - val_accuracy: 0.6429
# Epoch 498/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.5441 - accuracy: 0.8743 - val_loss: 1.3363 - val_accuracy: 0.6429
# Epoch 499/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.5059 - accuracy: 0.9042 - val_loss: 1.2801 - val_accuracy: 0.4048
# Epoch 500/500
# 6/6 [==============================] - 0s 20ms/step - loss: 0.4455 - accuracy: 0.9581 - val_loss: 1.3079 - val_accuracy: 0.3810

# %% [markdown]
# After the training, we can evaluate the regularized NN use the following command.

# %%
cat_model_regu.evaluate(test_x,test_y)
# Out:
# 2/2 [==============================] - 0s 22ms/step - loss: 0.8157 - accuracy: 0.8000
# [0.8156929016113281, 0.800000011920929]

# %% [markdown]
# The expected accuracy is highter than 0.8.
